# %% [markdown]
# # Python Basics

# %% [markdown]
# ## Brief History of Python
#
#
# *   Invented in the Netherlands, early 90s by Guido van Rossum
# *   Named after Monty Python
# *   Open sourced from the beginning
# *   Considered a scripting language, but is much more
# *   Scalable, object oriented and functional from the beginning
# *   Used by Google from the beginning
# *   Increasingly popular

# %% [markdown]
# ## Python Keywords
#
#
#
#
#
#
# *  There are the reserved words (can not be used as identifier) in Python
# *  These words are case sensitive
# ![python-keywords.png](data:image/png;base64,...)

# %% [markdown]
# ## Python Identifiers
#
#
#
#
#
#
# Name given to entities like class, functions, variables etc. in Python
# ###  Rules for writing identifiers
# * Can be a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore )
# * myClass, var_1 and print_this_to_screen, all are valid examples
# * Cannot start with a digit
# * 1variable is invalid, but variable1 is perfectly fine
# * Keywords cannot be used as identifiers
# * Cannot use special symbols like !,@, #, $,% etc. in our identifier
# * Can be of any length.

# %% [markdown]
# ## Things to care about
#
#
#
#
#
#
#
# * Python is a case sensitive language
# * Variable and variable are not same
# * Multiple words can be separated using an underscore, “this_is_a_long_variable_example” .

# %% [markdown]
# ## Python Variables
#
#
#
#
#
#
# * Variable is a named location used to store data in the memory
# * Alternatively, variables are the containers that holds data which can be changed later throughout the programming
# * In Python, variables do not need declaration to reserve memory space.
# * The "variable declaration" or "variable initialization" happens automatically when we assign a value to a variable.
# *  We use the assignment operator = to assign the value to a variable.

# %% [markdown]
# ## Python Basic Data-types
#
#
# ### Integers (default for numbers)
#
#
#
#
# ### Floats
#
#
#
#
# ### Strings
# * Can use “ ” or  ‘’ to specify with “abc” == ‘abc’
# * Unmatched can occur within the string: “matt’s”
# * Use triple double-quotes for multi-line strings or strings than contain both ‘ and “ inside of them:
# “““a‘b“c”””
#
#
# * Instead of curly braces { }, indentations are used to represent a block

# %%
z=5//2
print ("value of z is:",z)
# Out:
# value of z is: 2

# %%
z=5/2
print ("value of z is:",z)
# Out:
# value of z is: 2.5

# %%
my_str="I am Sajid"
print (my_str)
# Out:
# I am Sajid

# %%
my_str='I am Sajid'
print (my_str)
# Out:
# I am Sajid

# %%
my_str="""He said to me: "I won't come tomorrow"""
print (my_str)
# Out:
# He said to me: "I won't come tomorrow

# %% [markdown]
# ### Python Comments
#
#
#
#
#
#
# * Start comments with #, rest of line is ignored
# * Can include a “documentation string” as the first line of a new function or class you define
# * Development environments, debugger, and other tools use it: it’s good style to include one

# %%
""" I am just explaining variable types:
 I am a comment
 I am writing these functions for tutorials """
z=5//2
print (z)
# Out:
# 2

# %% [markdown]
# ### Python Collections
#
# Python Collections allow us to place multiple data objects in one object that we can access or work across. There are a variety of built-in collections, and we will discuss three of them: lists, tuples, and dictionaries. Later, we will introduce another method of data collection using arrays from a library called NumPy.

# %% [markdown]
# ## Python Lists
#
#
#
#
#
#
# * Python lists are sequences of items.
#
# * Almost all computer languages have a sequence structure like this, sometimes called an array
#
# * Usually, array is homogeneous (store data with the same type) and fixed size, Python list is heterogeneous (store data with different types) and dynamic (can grow or shrink).

# %% [markdown]
# ### Basic List Principles
#
#
#
#
#
#
#
# * A list is a sequence of items stored as a single object.
#
# * Items in a list can be accessed by indexing, and sublists can be accessed by slicing.
#
# * Lists are mutable; individual items or entire slices can be replaced through assignment statements.

# %%
list_1=[3, 4, 5, 6]
print ("my list is:", list_1)
# Out:
# my list is: [3, 4, 5, 6]

# %% [markdown]
# ### List Operations
#
#
# ![list1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Append in list

# %%
list_1.append(100)
print ("list_1 is:",list_1)
# Out:
# list_1 is: [3, 4, 5, 6, 100]

# %%
list_1.append(0)
print ("list_1 is:",list_1)
# Out:
# list_1 is: [3, 4, 5, 6, 100, 0]

# %% [markdown]
# ### List Sorting

# %%
list_1.sort()
print (list_1)
# Out:
# [0, 3, 4, 5, 6, 100]

# %% [markdown]
# ### Reverse a list

# %%
list_1.reverse()
print (list_1)
# Out:
# [100, 6, 5, 4, 3, 0]

# %% [markdown]
# ### Return Index

# %%
list_1.index(0)
# Out:
# 5

# %%
list_1
# Out:
# [100, 6, 5, 4, 3, 0]

# %% [markdown]
# ### Insert

# %%
list_1.insert(3, 230)
print (list_1)
# Out:
# [100, 6, 5, 230, 4, 3, 0]

# %%
list_1.insert(3, 50)
print (list_1)
# Out:
# [100, 6, 5, 50, 230, 4, 3, 0]

# %%
list_1.insert(3, 5)
print (list_1)
# Out:
# [100, 6, 5, 5, 50, 230, 4, 3, 0]

# %% [markdown]
# ### Count

# %%
list_1.count(5)
# Out:
# 2

# %% [markdown]
# ### Remove

# %%
list_1.remove(50)

# %%
list_1.remove(5)
print (list_1)
# Out:
# [100, 6, 5, 230, 4, 3, 0]

# %% [markdown]
# ### Pop

# %%
list_1.pop(2)
# Out:
# 5

# %%
list_1
# Out:
# [100, 6, 230, 4, 3, 0]

# %% [markdown]
# ### Number of elements

# %%
print ("total numbe of elements in list_1 are:", len(list_1))
# Out:
# total numbe of elements in list_1 are: 6

# %% [markdown]
# ## Tuples
#
#
#
#
#
#
#
# * Tuples are non-mutable lists (like strings), e.g., (1,'a',3)
#
# * Indexing and slicing
#
# * Empty tuple (), one-element tuple (1,).
#
# * Note that it is not enough to use (1) to represent one-element tuple

# %%
tuple_1=(3, 4, 6,  5,  6)

# %%
tuple_1
# Out:
# (3, 4, 6, 5, 6)

# %%
tuple_1.index(5)
# Out:
# 2

# %%
tuple_1.count(6)
# Out:
# 2

# %%
len(tuple_1)
# Out:
# 5

# %%
min(tuple_1)
# Out:
# 3

# %%
max(tuple_1)
# Out:
# 6

# %%
del(tuple_1)

# %% [markdown]
# ### Tuple Operations
# ![tuple.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Dictionaries
#
#
#
#
#
#
#
# * In sequences, we look up data by positions, or index.
#
# * Sometimes, we need more flexible way. For example, retrieve students based on ID number.
#
# * The data (ID number) we used for indexing is called key, other parts (student info) are called value.
#
# * A collection associated with arbitrary keys is called a mapping. Python dictionary is a mapping.
#
# *  Other languages have hashes or associative arrays for mapping

# %%
price = {
    "apple": 1.5,
    "orange": 1.25,
    "banana": 0.5
}
print ("apple costs $", price ["apple"])
# Out:
# apple costs $ 1.5

# %% [markdown]
# ### Dictionary Basics
#
#
#
#
#
#
#
# * Syntax:
#  * pwd = { "guido": "supercomputer",
# "turing": "genius",
#  "bill": "monopoly" }
#
# * Keys should be non-mutable built-in data type, such as strings, numbers, tuples, etc.
#
# * Values can be any data type.
#
# * Indexing:  mydic[key], e.g., pwd ["turing"]

# %% [markdown]
# ### Dictionary is Mutable

# %% [markdown]
# ### Change value

# %%
price["apple"]=34

# %%
print ("apple costs $", price ["apple"])
# Out:
# apple costs $ 34

# %% [markdown]
# ### Added new key value pair

# %%
price["grapes"]=15

# %%
price
# Out:
# {'apple': 34, 'orange': 1.25, 'banana': 0.5, 'grapes': 15}

# %% [markdown]
# ### Delete key-value pair

# %%
del price["orange"]

# %%
price
# Out:
# {'apple': 34, 'banana': 0.5, 'grapes': 15}

# %% [markdown]
# ### Delete all elements of a dictionary

# %%
price.clear()

# %%
price
# Out:
# {'apple': 1.5, 'orange': 1.25, 'banana': 0.5}

# %%
price={}

# %%
price
# Out:
# {}

# %% [markdown]
# ### Dictionary Operations
# ![dict1.jpeg](data:image/jpeg;base64,...)

# %%
price
# Out:
# {'apple': 1.5, 'orange': 1.25, 'banana': 0.5, 'grapes': 15}

# %%
print(price.__contains__('orange'))
# Out:
# True

# %%
print(price.__contains__('sajid'))
# Out:
# False

# %%
if "apple" in price: 
    print ("key is present")
else:
    print("key not present")
# Out:
# key is present

# %% [markdown]
# ### Get All Keys

# %%
price.keys()
# Out:
# dict_keys(['apple', 'orange', 'banana', 'grapes'])

# %% [markdown]
# ### Return all values

# %%
price.values()
# Out:
# dict_values([1.5, 1.25, 0.5, 15])

# %% [markdown]
# ### Return all items

# %%
price.items()
# Out:
# dict_items([('apple', 1.5), ('orange', 1.25), ('banana', 0.5), ('grapes', 15)])

# %%
price.get("glass", "Not Found")
# Out:
# 'Not Found'

# %% [markdown]
# ## Sets
#
#
#
#
#
#
#
# * A set is an unordered collection of items. Every element is unique and must be immutable.
#
# *  However, the set itself is mutable. We can add or remove items from it.
#
# * Sets can be used to perform mathematical set operations like union, intersection, symmetric difference etc.
#
# * You can explore more about sets at https://www.w3schools.com/python/python_sets.asp

# %% [markdown]
# ### Set Creation
#
#
#
#
#
#
#
# * A set is created by placing all the elements inside curly braces (), separated by comma or by using the built-in function set().
# * The elements can be of different types (integer, float, tuple, string etc.).
# * But a set cannot have a mutable element, like list, set or dictionary, as its element.

# %%
s = set((1,  3, 5,6,2,1,5,3))  # create set from tuple
print(s)
# Out:
# {1, 2, 3, 5, 6}

# %% [markdown]
#  print ("original list_1:", list_1 )

# %%
list_1.append(6)

# %%
 print ("original list_1:", list_1 )
# Out:
# original list_1: [100, 6, 230, 4, 3, 0, 6]

# %%
set_1=set(list_1)
print (set_1)
# Out:
# {0, 3, 100, 4, 6, 230}

# %% [markdown]
# ###Set Operations
# ![PythonSetOperators.png](data:image/png;base64,...)
